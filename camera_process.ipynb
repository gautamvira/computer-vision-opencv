# %%
import numpy as np
import cv2

# %%
cap = cv2.VideoCapture(1)

while True:
    ret, frame = cap.read()
    cv2.imshow('WebCam', frame)
    if cv2.waitKey(1) == ord('q'):
        break
cv2.destroyAllWindows()
cap.release()
# Out:
# 2025-01-19 16:21:00.311 Python[3060:77728] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
